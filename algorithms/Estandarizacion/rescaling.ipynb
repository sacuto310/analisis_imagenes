# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

image_data = nib.load('../images/T1.nii.gz').get_fdata()
image_data_v2 = nib.load('../images/T1_V2.nii.gz').get_fdata()

# %%
min_value = image_data.min()
max_value = image_data.max()

image_data_rescaled = (image_data - min_value) / (max_value - min_value)


min_value = image_data_v2.min()
max_value = image_data_v2.max()

image_data_rescaled_2 = (image_data_v2 - min_value) / (max_value - min_value)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 8))
ax1.imshow(image_data_rescaled[:,:,25])
ax1.set_title('Rescaling')
ax2.imshow(image_data[:,:,25])
ax2.set_title('Original')
# Out:
# Text(0.5, 1.0, 'Original')

# %%
plt.hist(image_data_rescaled[image_data_rescaled>0.01].flatten(),100, alpha=0.5)
plt.hist(image_data_rescaled_2[image_data_rescaled_2>0.01].flatten(),100, alpha=0.5)
# Out:
# (array([2.84723e+05, 1.68760e+05, 1.31329e+05, 1.18536e+05, 1.14387e+05,
#         1.11942e+05, 1.10655e+05, 1.11309e+05, 1.13384e+05, 1.17809e+05,
#         1.22324e+05, 1.29397e+05, 1.37571e+05, 1.46574e+05, 1.58211e+05,
#         1.69862e+05, 1.77869e+05, 1.80955e+05, 1.77631e+05, 1.70279e+05,
#         1.58717e+05, 1.48248e+05, 1.38725e+05, 1.32200e+05, 1.28055e+05,
#         1.28623e+05, 1.29952e+05, 1.33466e+05, 1.30823e+05, 1.16329e+05,
#         9.59370e+04, 7.75390e+04, 6.19190e+04, 4.92420e+04, 3.87380e+04,
#         3.03440e+04, 2.37950e+04, 1.93200e+04, 1.56680e+04, 1.25800e+04,
#         1.02140e+04, 8.29800e+03, 6.86200e+03, 5.62800e+03, 4.72200e+03,
#         3.86100e+03, 3.10100e+03, 2.35500e+03, 1.96300e+03, 1.50700e+03,
#         1.17900e+03, 9.69000e+02, 8.09000e+02, 6.47000e+02, 5.74000e+02,
#         4.72000e+02, 3.79000e+02, 3.34000e+02, 2.80000e+02, 2.23000e+02,
#         2.24000e+02, 1.89000e+02, 1.26000e+02, 1.46000e+02, 9.90000e+01,
# ...
